# %%
from project.circuit_builders.clifford_T import build_clifford_T_circuit

qc = build_clifford_T_circuit(4,20)

qc.draw(fold=-1)
# Out:
#      ┌───┐┌───┐┌───┐┌───┐┌───┐
# q_0: ┤ X ├┤ S ├┤ S ├┤ T ├┤ S ├─────────────────────────
#      └─┬─┘├───┤└───┘└───┘└───┘┌───┐
# q_1: ──■──┤ T ├───────────────┤ X ├────────────────────
#           ├───┤┌───┐┌───┐┌───┐└─┬─┘┌───┐┌───┐┌───┐┌───┐
# q_2: ──■──┤ H ├┤ S ├┤ T ├┤ H ├──┼──┤ T ├┤ S ├┤ T ├┤ T ├
#      ┌─┴─┐├───┤├───┤├───┤└───┘  │  ├───┤└───┘└───┘└───┘
# q_3: ┤ X ├┤ T ├┤ T ├┤ S ├───────■──┤ H ├───────────────
#      └───┘└───┘└───┘└───┘          └───┘
