# %%
# import sys
# sys.path.append('../../')

# from circuit_builders.builder import build_clifford_T_circuit

# qc = build_clifford_T_circuit(num_ops=10, num_qubits=4)
# qc.draw(fold = -1, output="mpl", filename = 'cliffordT.png')

# %%
# !which python
# Out:
# /home/amaciejunes/Desktop/projects/J7_Sampling/.venv/bin/python
